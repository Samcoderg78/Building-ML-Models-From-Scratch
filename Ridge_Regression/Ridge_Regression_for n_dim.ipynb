# %% [markdown]
# ## Ridge Regression for n-dimensional Data
#
# ### Key Components
# #### Data Loading and Preparation
#
# * Loads the diabetes dataset from scikit-learn
# * Splits into features (X) and target (y)

# %%
from sklearn.datasets import load_diabetes

# %%
X, y = load_diabetes(return_X_y = True)

# %% [markdown]
# ### Model Training
# * Uses scikit-learn's Ridge implementation
# * Sets regularization parameter alpha=0.39
# * Fits model on training data

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
ridge = Ridge(0.39)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 18)

# %%
ridge.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.39)

# %%
y_pred = ridge.predict(X_test)

# %% [markdown]
# ### Evaluation
# * Evaluates model using R² score
# * Achieves score of ~0.43

# %%
r2_score(y_test, y_pred)
# Out:
# 0.43025084828535554

# %% [markdown]
# ## Custom Implementation
#
# * Implements Ridge Regression from scratch
# * Handles n-dimensional input
# * Uses matrix operations for coefficient calculation
# * Includes L2 regularization term

# %%
import numpy as np

# %%
class Ridge:
    def __init__(self,alpha):
        self.alpha = alpha
        self.coef_ = None
        self.intercept_ = None

    def fit(self, X_train, y_train):
        X_train = np.insert(X_train, 0, 1, axis=1)

        I = np.identity(X_train.shape[1])
        I[0][0]=0
        result = np.linalg.inv(np.dot(X_train.T , X_train) + self.alpha * I).dot(X_train.T).dot(y_train)
        self.coef_ = result[1:]
        self.intercept_ = result[0]
        
    def predict(self, X_test):
        return np.dot(X_test, self.coef_) + self.intercept_

# %%
ridge_n_dim = Ridge(0.39)

# %%
ridge_n_dim.fit(X_train, y_train)

# %%
y_pred2 = ridge_n_dim.predict(X_test)

# %%
r2_score(y_test, y_pred2)
# Out:
# 0.43025084828535587
